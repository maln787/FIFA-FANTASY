# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_20 = pd.read_csv('players_20.csv')
df_21 = pd.read_csv('players_21.csv')
df_22 = pd.read_csv('players_22.csv')
# Out:
# /Users/harshitlikhar/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (25,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_22.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
df_20['version'] = 2020
df_21['version'] = 2021
df_22['version'] = 2022

# %%
df_main = df_20.append(df_21)
df_main = df_main.append(df_22)

# %%
print('df_20',df_20.shape)
print('df_21',df_21.shape)
print('df_22',df_22.shape)
print('-------------------')
print('df_main',df_main.shape)
# Out:
# df_20 (18483, 111)
# df_21 (18944, 111)
# df_22 (19239, 111)
# -------------------
# df_main (56666, 111)

# %%
df_main.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   56666.000000  56666.000000  56666.000000  5.610500e+04   56140.000000
# mean   225901.574789     65.879804     71.219320  2.752277e+06    9297.940862
# std     27827.213605      6.947807      6.115033  7.069195e+06   20274.027059
# min        41.000000     47.000000     47.000000  8.000000e+03     500.000000
# 25%    209839.000000     61.000000     67.000000  4.250000e+05    1000.000000
# 50%    231652.000000     66.000000     71.000000  8.750000e+05    3000.000000
# 75%    246065.750000     70.000000     75.000000  2.000000e+06    8000.000000
# max    264640.000000     94.000000     95.000000  1.940000e+08  560000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  56666.000000  56666.000000  56666.000000   56140.000000  55755.000000
# mean      25.239403    181.279109     75.070801   47948.525953      1.369671
# ...

# %% [markdown]
# ### NULL Values des

# %%
print(df_main.isnull().sum()[:50])
# Out:
# sofifa_id                         0
# player_url                        0
# short_name                        0
# long_name                         0
# player_positions                  0
# overall                           0
# potential                         0
# value_eur                       561
# wage_eur                        526
# age                               0
# dob                               0
# height_cm                         0
# weight_kg                         0
# club_team_id                    526
# club_name                       526
# league_name                     526
# league_level                    911
# club_position                   526
# club_jersey_number              526
# club_loaned_from              53758
# club_joined                    3434
# club_contract_valid_until       526
# nationality_id                    0
# nationality_name                  0
# nation_team_id                53653
# nation_position               53653
# ...

# %%
df_all = df_main.copy()

# %%
df_main['league_level'].unique()
# Out:
# array([ 1., nan,  2.,  3.,  4.,  5.])

# %%
df_main = df_main[~df_main['league_level'].isnull()]

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55755 entries, 0 to 19238
# Columns: 111 entries, sofifa_id to version
# dtypes: float64(16), int64(45), object(50)
# memory usage: 47.6+ MB

# %%
#df_main.to_csv("df_main.csv")

# %%
import missingno as msno
msno.bar(df_copy)
# Out:
# <AxesSubplot:>

# %%
df_copy = df_main.copy()

# %%
df_copy = df_copy.drop(['nation_jersey_number', 'nation_position', 'nation_team_id', 'player_tags','player_traits', 'nation_logo_url'], axis = 1)

# %%
df_copy.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, CF, ST
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 2          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 3          E. Hazard                          Eden Hazard           LW, CF
# 4       K. De Bruyne                      Kevin De Bruyne          CAM, CM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
df_copy[df_copy['sofifa_id']== 20801]
# Out:
#    sofifa_id                                         player_url  \
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name player_positions  \
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
#
#    overall  potential   value_eur  wage_eur  age  ...   lcb    cb   rcb    rb  \
# 1       93         93  58500000.0  410000.0   34  ...  54+3  54+3  54+3  61+3
# 1       92         92  63000000.0  220000.0   35  ...  54+3  54+3  54+3  61+3
# 2       91         91  45000000.0  270000.0   36  ...  53+3  53+3  53+3  60+3
#
#      gk                                    player_face_url  \
# ...

# %%
df_copy['club_loaned_from'] = df_copy['club_loaned_from'].fillna('Not on Loan')

# %%
min(df_copy[~df_copy['goalkeeping_speed'].isnull()]['goalkeeping_speed'])
# Out:
# 12.0

# %%
df_copy[df_copy['physic'].isnull()][['player_positions']].value_counts()
# Out:
# player_positions
# GK                  6157
# dtype: int64

# %%
df_copy['goalkeeping_speed'] = df_copy['goalkeeping_speed'].fillna(5)

# %%
'''
min:
    pace:  24
    shooting: 15
    passing: 24
    dribbling: 23
    defending: 15
    physic: 27
'''
df_copy['pace'] = df_copy['pace'].fillna(10)
df_copy['shooting'] = df_copy['shooting'].fillna(10)
df_copy['passing'] = df_copy['passing'].fillna(10)
df_copy['defending'] = df_copy['defending'].fillna(10)
df_copy['physic'] = df_copy['physic'].fillna(25)
df_copy['dribbling'] = df_copy['dribbling'].fillna(10)

# %%
df_copy['club_joined'] = df_copy['club_joined'].fillna('Not Known')

# %%
df_copy['release_clause_eur'] = df_copy['release_clause_eur'].fillna(df_copy['release_clause_eur'].mean())

# %%
#df_copy.to_csv("df_main.csv")
